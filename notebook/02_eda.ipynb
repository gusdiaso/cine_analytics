# %% [markdown]
# ### Analisando os Dados

# %%
import pandas as pd 

df = pd.read_csv("../data/cinema_processed.csv")

df.describe().round(1)
# Out:
#        Released_Year  Runtime  IMDB_Rating  Meta_score  No_of_Votes  \
# count          898.0    898.0        898.0       898.0        898.0
# mean          1993.0    124.2          7.9        77.6     295491.4
# std             21.8     28.4          0.3        11.5     329832.7
# min           1921.0     45.0          7.6        28.0      25088.0
# 25%           1980.0    104.0          7.7        72.0      64159.0
# 50%           1999.0    120.0          7.9        78.0     165937.0
# 75%           2010.0    138.0          8.1        85.0     419467.2
# max           2020.0    321.0          9.2       100.0    2303232.0
#
#              Gross  Faixa_etaria
# count        898.0         898.0
# mean    65717749.2           1.1
# std    105699422.4           0.8
# min         1305.0           0.0
# 25%      5573757.5           0.0
# 50%     23457439.5           1.0
# 75%     74987001.0           2.0
# max    936662225.0           2.0

# %% [markdown]
# Apenas com esses dados, já conseguimos algumas informações importantes:
#
# - Nosso dataset tem filme predominantemente recentes, 1980 até 2020
# - A media de duração dos filmes é mais ou menos 2h, possuem filmes com grande diferença de tempo
# - O IMDB varia de 7.6 a 9.2, isso indica que os filmes do dataset são todos bem avaliados
# - Grande parte dos filmes tambem possuem MetaScore acima de 72, que é uma boa pontuação
# - Existe uma diferença muito grande de votos entre o min e o max, possiveis filmes extremamente famosos no dataset
# - Tambem há diferença absurda entre o faturamento min e max, o que reforça a ideia de filmes muito famosos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid") 


numericas = ['IMDB_Rating', 'Meta_score', 'No_of_Votes', 'Gross', 'Runtime', 'Released_Year']

for col in numericas:
    plt.figure(figsize=(14,5))
    ax = sns.histplot(df[col],bins=40, color="blue", kde=True)
    ax.xaxis.set_major_locator(plt.MaxNLocator(20))
    ax.grid(True, linestyle='--', alpha=0.8)
    plt.title(f'Distribuição de {col}')
    plt.ylabel("Contagem")
    plt.show()

# %% [markdown]
# Se analizarmos bem os graficos, reparamos que a maior parte dos filmes possuem numero de votos e faturamento concentrado a esquerda, isso significa que na verdade os filmes em sua maioria possuem votos e faturamento em quantidade razoável.

# %%
for col in numericas:
    plt.figure(figsize=(10,1))
    sns.boxplot(x=df[col], color="blue")
    plt.title(f'Boxplot de {col}')
    plt.show()

# %%
generos = df['Genre'].str.split(',').explode()
generos = generos.str.strip()

freq_genero = generos.value_counts()

plt.figure(figsize=(18,6))
sns.barplot(x=freq_genero.index, y=freq_genero.values, color="green")
plt.title('Distribuição de Gêneros')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# Esses boxplots indicam que:
#
# - Poucos filmes possuem IMDB maior que 8.7 ( o que leva a isso? )
# - Dificilmente um filme terá MetaScore menor que 5.5
# - Apenas alguns filmes possuem uma grande quantidade de votos e faturamento ( o que leva a isso? )
# - Poucos filmes tem duração acima de 3h
# - Maior parte dos filmes da categoria Drama

# %%
df.sort_values(by="IMDB_Rating", ascending=False).head(10)
# Out:
#                                         Series_Title  Released_Year  \
# 0                                      The Godfather           1972
# 1                                    The Dark Knight           2008
# 2                             The Godfather: Part II           1974
# 3                                       12 Angry Men           1957
# 4      The Lord of the Rings: The Return of the King           2003
# 5                                       Pulp Fiction           1994
# 6                                   Schindler's List           1993
# 7                                          Inception           2010
# 8                                         Fight Club           1999
# 9  The Lord of the Rings: The Fellowship of the Ring           2001
#
#   Certificate  Runtime                      Genre  IMDB_Rating  \
# 0           A      175               Crime, Drama          9.2
# 1          UA      152       Action, Crime, Drama          9.0
# 2           A      202               Crime, Drama          9.0
# 3           U       96               Crime, Drama          9.0
# 4           U      201   Action, Adventure, Drama          8.9
# 5           A      154               Crime, Drama          8.9
# 6           A      195  Biography, Drama, History          8.9
# 7          UA      148  Action, Adventure, Sci-Fi          8.8
# 8           A      139                      Drama          8.8
# 9           U      178   Action, Adventure, Drama          8.8
#
#                                             Overview  Meta_score  \
# 0  An organized crime dynasty's aging patriarch t...       100.0
# 1  When the menace known as the Joker wreaks havo...        84.0
# 2  The early life and career of Vito Corleone in ...        90.0
# 3  A jury holdout attempts to prevent a miscarria...        96.0
# 4  Gandalf and Aragorn lead the World of Men agai...        94.0
# 5  The lives of two mob hitmen, a boxer, a gangst...        94.0
# 6  In German-occupied Poland during World War II,...        94.0
# 7  A thief who steals corporate secrets through t...        74.0
# 8  An insomniac office worker and a devil-may-car...        66.0
# 9  A meek Hobbit from the Shire and eight compani...        92.0
#
#                Director              Star1                 Star2  \
# 0  Francis Ford Coppola      Marlon Brando             Al Pacino
# 1     Christopher Nolan     Christian Bale          Heath Ledger
# 2  Francis Ford Coppola          Al Pacino        Robert De Niro
# 3          Sidney Lumet        Henry Fonda           Lee J. Cobb
# 4         Peter Jackson        Elijah Wood       Viggo Mortensen
# 5     Quentin Tarantino      John Travolta           Uma Thurman
# 6      Steven Spielberg        Liam Neeson         Ralph Fiennes
# 7     Christopher Nolan  Leonardo DiCaprio  Joseph Gordon-Levitt
# 8         David Fincher          Brad Pitt         Edward Norton
# 9         Peter Jackson        Elijah Wood          Ian McKellen
#
#                Star3             Star4  No_of_Votes        Gross  \
# 0         James Caan      Diane Keaton      1620367  134966411.0
# 1      Aaron Eckhart     Michael Caine      2303232  534858444.0
# 2      Robert Duvall      Diane Keaton      1129952   57300000.0
# 3      Martin Balsam      John Fiedler       689845    4360000.0
# 4       Ian McKellen     Orlando Bloom      1642758  377845905.0
# 5  Samuel L. Jackson      Bruce Willis      1826188  107928762.0
# 6       Ben Kingsley  Caroline Goodall      1213505   96898818.0
# 7        Elliot Page      Ken Watanabe      2067042  292576195.0
# 8          Meat Loaf      Zach Grenier      1854740   37030102.0
# 9      Orlando Bloom         Sean Bean      1661481  315544750.0
#
#    Faixa_etaria Faixa_etaria_texto
# 0             2             Adulto
# 1             1       Adolescentes
# 2             2             Adulto
# 3             0              Livre
# 4             0              Livre
# 5             2             Adulto
# 6             2             Adulto
# 7             1       Adolescentes
# 8             2             Adulto
# 9             0              Livre

# %% [markdown]
# Praticamente todos os filmes de sucesso no IMDB são de Drama, entao com certeza o proximo filme produzido necessita ser de drama

# %%
df.sort_values(by="Gross", ascending=False).head(10)
# Out:
#                                    Series_Title  Released_Year Certificate  \
# 426  Star Wars: Episode VII - The Force Awakens           2015           U
# 56                            Avengers: Endgame           2019          UA
# 554                                      Avatar           2009          UA
# 57                       Avengers: Infinity War           2018          UA
# 581                                     Titanic           1997          UA
# 325                                The Avengers           2012          UA
# 797                               Incredibles 2           2018          UA
# 1                               The Dark Knight           2008          UA
# 519                                   Rogue One           2016          UA
# 60                        The Dark Knight Rises           2012          UA
#
#      Runtime                         Genre  IMDB_Rating  \
# 426      138     Action, Adventure, Sci-Fi          7.9
# 56       181      Action, Adventure, Drama          8.4
# 554      162    Action, Adventure, Fantasy          7.8
# 57       149     Action, Adventure, Sci-Fi          8.4
# 581      194                Drama, Romance          7.8
# 325      143     Action, Adventure, Sci-Fi          8.0
# 797      118  Animation, Action, Adventure          7.6
# 1        152          Action, Crime, Drama          9.0
# 519      133     Action, Adventure, Sci-Fi          7.8
# 60       164             Action, Adventure          8.4
#
#                                               Overview  Meta_score  \
# 426  As a new threat to the galaxy rises, Rey, a de...        80.0
# 56   After the devastating events of Avengers: Infi...        78.0
# 554  A paraplegic Marine dispatched to the moon Pan...        83.0
# 57   The Avengers and their allies must be willing ...        68.0
# 581  A seventeen-year-old aristocrat falls in love ...        75.0
# 325  Earth's mightiest heroes must come together an...        69.0
# 797  The Incredibles family takes on a new mission ...        80.0
# 1    When the menace known as the Joker wreaks havo...        84.0
# 519  The daughter of an Imperial scientist joins th...        65.0
# 60   Eight years after the Joker's reign of anarchy...        78.0
#
#               Director              Star1              Star2  \
# 426        J.J. Abrams       Daisy Ridley        John Boyega
# 56       Anthony Russo          Joe Russo  Robert Downey Jr.
# 554      James Cameron    Sam Worthington        Zoe Saldana
# 57       Anthony Russo          Joe Russo  Robert Downey Jr.
# 581      James Cameron  Leonardo DiCaprio       Kate Winslet
# 325        Joss Whedon  Robert Downey Jr.        Chris Evans
# 797          Brad Bird    Craig T. Nelson       Holly Hunter
# 1    Christopher Nolan     Christian Bale       Heath Ledger
# 519     Gareth Edwards     Felicity Jones         Diego Luna
# 60   Christopher Nolan     Christian Bale          Tom Hardy
#
#                   Star3               Star4  No_of_Votes        Gross  \
# 426         Oscar Isaac    Domhnall Gleeson       860823  936662225.0
# 56          Chris Evans        Mark Ruffalo       809955  858373000.0
# 554    Sigourney Weaver  Michelle Rodriguez      1118998  760507625.0
# 57      Chris Hemsworth        Mark Ruffalo       834477  678815482.0
# 581          Billy Zane         Kathy Bates      1046089  659325379.0
# 325  Scarlett Johansson       Jeremy Renner      1260806  623279547.0
# 797        Sarah Vowell         Huck Milner       250057  608581744.0
# 1         Aaron Eckhart       Michael Caine      2303232  534858444.0
# 519          Alan Tudyk          Donnie Yen       556608  532177324.0
# 60        Anne Hathaway         Gary Oldman      1516346  448139099.0
#
#      Faixa_etaria Faixa_etaria_texto
# 426             0              Livre
# 56              1       Adolescentes
# 554             1       Adolescentes
# 57              1       Adolescentes
# 581             1       Adolescentes
# 325             1       Adolescentes
# 797             1       Adolescentes
# 1               1       Adolescentes
# 519             1       Adolescentes
# 60              1       Adolescentes

# %% [markdown]
# E praticamente todos filmes que tiveram o maior faturamento é de Ação + Aventura

# %%
df.sort_values(by="Meta_score", ascending=False).head(10)
# Out:
#                Series_Title  Released_Year Certificate  Runtime  \
# 0             The Godfather           1972           A      175
# 117            Citizen Kane           1941          UA      119
# 114                 Vertigo           1958           A      128
# 111      Lawrence of Arabia           1962           U      228
# 77              Rear Window           1954           U      112
# 400  Sweet Smell of Success           1957    Approved       96
# 386          Il conformista           1970          UA      113
# 258     Fanny och Alexander           1982           A      188
# 244   Trois couleurs: Rouge           1994           U       99
# 48               Casablanca           1942           U      102
#
#                            Genre  IMDB_Rating  \
# 0                   Crime, Drama          9.2
# 117               Drama, Mystery          8.3
# 114   Mystery, Romance, Thriller          8.3
# 111  Adventure, Biography, Drama          8.3
# 77             Mystery, Thriller          8.4
# 400             Drama, Film-Noir          8.0
# 386                        Drama          8.0
# 258                        Drama          8.1
# 244      Drama, Mystery, Romance          8.1
# 48           Drama, Romance, War          8.5
#
#                                               Overview  Meta_score  \
# 0    An organized crime dynasty's aging patriarch t...       100.0
# 117  Following the death of publishing tycoon Charl...       100.0
# 114  A former police detective juggles wrestling wi...       100.0
# 111  The story of T.E. Lawrence, the English office...       100.0
# 77   A wheelchair-bound photographer spies on his n...       100.0
# 400  Powerful but unethical Broadway columnist J.J....       100.0
# 386  A weak-willed Italian man becomes a fascist fl...       100.0
# 258  Two young Swedish children experience the many...       100.0
# 244  A model discovers a retired judge is keen on i...       100.0
# 48   A cynical expatriate American cafe owner strug...       100.0
#
#                   Director                   Star1                   Star2  \
# 0     Francis Ford Coppola           Marlon Brando               Al Pacino
# 117           Orson Welles            Orson Welles           Joseph Cotten
# 114       Alfred Hitchcock           James Stewart               Kim Novak
# 111             David Lean           Peter O'Toole           Alec Guinness
# 77        Alfred Hitchcock           James Stewart             Grace Kelly
# 400  Alexander Mackendrick          Burt Lancaster             Tony Curtis
# 386    Bernardo Bertolucci  Jean-Louis Trintignant      Stefania Sandrelli
# 258         Ingmar Bergman             Bertil Guve         Pernilla Allwin
# 244   Krzysztof Kieslowski             Irène Jacob  Jean-Louis Trintignant
# 48          Michael Curtiz         Humphrey Bogart          Ingrid Bergman
#
#                   Star3              Star4  No_of_Votes        Gross  \
# 0            James Caan       Diane Keaton      1620367  134966411.0
# 117   Dorothy Comingore    Agnes Moorehead       403351    1585634.0
# 114  Barbara Bel Geddes        Tom Helmore       364368    3200000.0
# 111       Anthony Quinn       Jack Hawkins       268085   44824144.0
# 77        Wendell Corey      Thelma Ritter       444074   36764313.0
# 400      Susan Harrison      Martin Milner        28137   23457439.5
# 386     Gastone Moschin      Enzo Tarascio        27067     541940.0
# 258  Kristina Adolphson     Börje Ahlstedt        57784    4971340.0
# 244    Frédérique Feder  Jean-Pierre Lorit        90729    4043686.0
# 48         Paul Henreid       Claude Rains       522093    1024560.0
#
#      Faixa_etaria Faixa_etaria_texto
# 0               2             Adulto
# 117             1       Adolescentes
# 114             2             Adulto
# 111             0              Livre
# 77              0              Livre
# 400             0              Livre
# 386             1       Adolescentes
# 258             2             Adulto
# 244             0              Livre
# 48              0              Livre

# %% [markdown]
# Novamente o Drama prevalece, entao acredito que um Filme que consiga misturar Drama, Ação e Aventura seja uma boa pedida, mas algo bem feito!

# %%
numericas = ["Released_Year","Runtime","IMDB_Rating","Meta_score","No_of_Votes","Gross","Faixa_etaria"]

correlacao = df[numericas].corr()

plt.figure(figsize=(10,8))        
sns.heatmap(correlacao, annot=True, cmap='Greens', fmt=".1f")  # fmt=".2f" mostra 2 casas decimais
plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# Aqui encontramos duas correlaçoes moderadas, NumeroVotos x IMBD de 0.5 e NumeroVotos x faturamento 0.6:
#
# - Há uma relação positiva moderada: filmes com mais votos tendem a ter nota ligeiramente maior, mas não é uma regra absoluta apenas uma tendência.
# - A relação é um pouco mais forte: filmes com mais votos tendem a faturar mais, porem tambem é uma tendência.

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='Faixa_etaria_texto', data=df, color="green").set_xlabel('Faixa etária')
plt.title('Distribuição de faixa etária')
plt.show()

# %%
pd.DataFrame({
    'Quantidade': df['Faixa_etaria_texto'].value_counts(),
    'Media_Gross': df.groupby('Faixa_etaria_texto')['Gross'].mean().round(2),
    'Media_IMDB': df.groupby('Faixa_etaria_texto')['IMDB_Rating'].mean().round(2),
    'Media_No_of_Votes': df.groupby('Faixa_etaria_texto')['No_of_Votes'].mean().round(2),
    'Media_Meta_score': df.groupby('Faixa_etaria_texto')['Meta_score'].mean().round(2),
})
# Out:
#                     Quantidade  Media_Gross  Media_IMDB  Media_No_of_Votes  \
# Faixa_etaria_texto
# Adolescentes               259  92665574.57        7.92          336021.37
# Adulto                     346  45320690.70        7.94          327751.53
# Livre                      293  65983604.01        7.98          221568.85
#
#                     Media_Meta_score
# Faixa_etaria_texto
# Adolescentes                   76.77
# Adulto                         76.60
# Livre                          79.54

# %% [markdown]
# Aqui conseguimos reparar que filmes do publico adolescente costumam faturar mais e a ter mais votos, porem filmes do publico livre possuem o IMDB e meta_score ligeiramente maior.
#
# Minha recomedação até o momento seria produzir um filme para adolescentes, com um drama bem feito, ação envolvente e aventura!

# %%
df[["Runtime", "Gross"]].sort_values(by="Gross", ascending=False).head(10).mean()
# Out:
# Runtime          153.4
# Gross      664071986.9
# dtype: float64

# %%
df[["Runtime", "IMDB_Rating"]].sort_values(by="IMDB_Rating", ascending=False).head(10).mean()
# Out:
# Runtime        164.00
# IMDB_Rating      8.93
# dtype: float64

# %%
df[["Runtime", "Meta_score"]].sort_values(by="Meta_score", ascending=False).head(10).mean()
# Out:
# Runtime       136.0
# Meta_score    100.0
# dtype: float64

# %% [markdown]
# Produzir um filme de aproximadamente 155 minutos!

# %%
nota_diretores = df.groupby('Director')['IMDB_Rating'].mean().sort_values(ascending=False)
print("Top 5 Diretores com maiores notas:")
print(nota_diretores.head(2))
# Out:
# Top 5 Diretores com maiores notas:
# Director
# Lana Wachowski    8.7
# Irvin Kershner    8.7
# Name: IMDB_Rating, dtype: float64

# %%
nota_diretores = df.groupby('Director')['Gross'].mean().sort_values(ascending=False)
print("Top 5 Diretores com maiores faturamentos:")
print(nota_diretores.head(2))
# Out:
# Top 5 Diretores com maiores faturamentos:
# Director
# Anthony Russo     5.512599e+08
# Gareth Edwards    5.321773e+08
# Name: Gross, dtype: float64

# %% [markdown]
# Aqui depende do objetivo, se o objetivo do filme for obter uma maior nota, recomendaria Lana Wachowski ou Irvin Kershner, caso seja o faturamento, recomendaria Anthony Russo ou Gareth Edwards

# %%
todos_atores = pd.concat([df['Star1'], df['Star2'], df['Star3'], df['Star4']]).reset_index(drop=True)

notas_repetidas = df['IMDB_Rating'].repeat(4).reset_index(drop=True)

df_atores = pd.DataFrame({
    'Actor': todos_atores,
    'IMDB_Rating': notas_repetidas
})

df_atores['Actor'] = df_atores['Actor'].str.strip()

media_atores = df_atores.groupby('Actor')['IMDB_Rating'].mean().sort_values(ascending=False)

print(media_atores.head(10))
# Out:
# Actor
# Elijah Wood           9.0
# John Travolta         9.0
# Lilly Wachowski       9.0
# Lin-Manuel Miranda    8.9
# Daveigh Chase         8.9
# Kátia Lund            8.9
# Suriya                8.9
# Éric Toledano         8.8
# Rob Minkoff           8.8
# Jean Reno             8.8
# Name: IMDB_Rating, dtype: float64

# %% [markdown]
# Para o elenco de atores que mais tiveram IMDB temos:
#
# - Lilly Wachowski
# - John Travolta
# - Elijah Wood
# - Suriya
# - Daveigh Chase
# - Lin-Manuel Miranda
# - Kátia Lund
# - Éric Toledano
# - Anthony Perkins
# - Tsutomu Tatsumi

# %%
todos_atores = pd.concat([df['Star1'], df['Star2'], df['Star3'], df['Star4']]).reset_index(drop=True)

notas_repetidas = df['Gross'].repeat(4).reset_index(drop=True)

df_atores = pd.DataFrame({
    'Actor': todos_atores,
    'Gross': notas_repetidas
})

df_atores['Actor'] = df_atores['Actor'].str.strip()

media_atores = df_atores.groupby('Actor')['Gross'].mean().sort_values(ascending=False)

print(media_atores.head(10))
# Out:
# Actor
# Michael Peña           936662225.0
# Mirai Shida            936662225.0
# Maria Doyle Kennedy    760507625.0
# Samantha Isler         760507625.0
# David Silverman        678815482.0
# Emilio Echevarría      678815482.0
# Kazuya Tsurumaki       678815482.0
# Scott Adsit            659325379.0
# Mehdi Nebbou           659325379.0
# Miori Takimoto         659325379.0
# Name: Gross, dtype: float64

# %% [markdown]
# Para o elenco de atores que mais tiveram fatura temos:
#
# - Michael Peña
# - Mirai Shida
# - Maria Doyle Kennedy
# - Samantha Isler
# - David Silverman
# - Emilio Echevarría
# - Kazuya Tsurumaki
# - Mehdi Nebbou
# - Scott Adsit
# - Miori Takimoto

# %% [markdown]
# ### Qual filme eu recomendaria?

# %%
df.sort_values(by=["IMDB_Rating", "Meta_score"], ascending=[False, False] ).head(2)
# Out:
#     Series_Title  Released_Year Certificate  Runtime         Genre  \
# 0  The Godfather           1972           A      175  Crime, Drama
# 3   12 Angry Men           1957           U       96  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 3          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director          Star1        Star2          Star3  \
# 0  Francis Ford Coppola  Marlon Brando    Al Pacino     James Caan
# 3          Sidney Lumet    Henry Fonda  Lee J. Cobb  Martin Balsam
#
#           Star4  No_of_Votes        Gross  Faixa_etaria Faixa_etaria_texto
# 0  Diane Keaton      1620367  134966411.0             2             Adulto
# 3  John Fiedler       689845    4360000.0             0              Livre

# %% [markdown]
# Recomendaria "The Godfather" baseado na pontuação IMDB e no MetaSore, isso levando em conta que a pessoa é adulta!

# %% [markdown]
# ### Quais são os principais fatores que estão relacionados com alta expectativa de faturamento de um filme?

# %% [markdown]
# Os principais fatores relacionados a um alto faturamento são:
#
# - Meta_score elevado: filmes bem avaliados pela crítica tendem a apresentar melhor desempenho financeiro, como evidenciado na matriz de correlação
# - Categorias populares: gêneros como Drama, Ação e Aventura se destacam, pois concentram a maioria dos filmes de grande sucesso
# - Elenco renomado: atores já reconhecidos pelo público, especialmente aqueles com histórico positivo em produções desses gêneros, aumentam a visibilidade do filme
# - Qualidade narrativa e produção: histórias bem construídas, que emocionam e envolvem a audiência, também se mostram determinantes para o sucesso de bilheteria

# %% [markdown]
# ### Quais insights podem ser tirados com a coluna Overview? É possível inferir o gênero do filme a partir dessa coluna?

# %% [markdown]
# A coluna Overview traz os resumos dos filmes e pode gerar alguns insights interessantes. Seria possível fazer uma análise de sentimento, para ver se descrições dos filmes de sucesso e entender o porque atraem mais público. Também dá para extrair palavras-chave que ajudam a identificar gêneros e tendências. Também é possível até tentar prever o gênero do filme usando técnicas de NLP (processamento de linguagem natural).

# %% [markdown]
# ### Explique como você faria a previsão da nota do imdb a partir dos dados. Quais variáveis e/ou suas transformações você utilizou e por quê? Qual tipo de problema estamos resolvendo (regressão, classificação)? Qual modelo melhor se aproxima dos dados e quais seus prós e contras? Qual medida de performance do modelo foi escolhida e por quê?

# %% [markdown]
# Para prever a nota do IMDB, eu trataria o problema como regressão, já que a nota é um valor numérico. As variáveis mais úteis seriam:
#
# - Meta_score (avaliação da crítica)
# - Runtime (duração do filme)
# - No_of_Votes (popularidade do filme)
# - Gross (faturamento)
# - Genre (transformado em variáveis dummies, pois é categórico)
#
# Essas variáveis foram escolhidas porque são objetivas, disponíveis antes do lançamento e têm relação com avaliação IMDB do filme<br>
# O modelo que eu utilizaria seria um Random Forest Regressor, porque ele consegue lidar bem com dados numéricos e categóricos, além de capturar relações não lineares, alem de ser robusto e ter boa performance sem muito ajuste.<br>
# A métrica escolhida seria o RMSE (Root Mean Squared Error), porque mostra de forma clara o erro médio das previsões na mesma escala da nota do IMDB
